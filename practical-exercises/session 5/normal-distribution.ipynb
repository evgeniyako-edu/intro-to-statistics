# %% [markdown]
# # Normal Distribution
#
# In this notebook, you'll familiarize yourself with one of the most important continuous distributions - the Normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# As you already know, a normally distributed random variable has two parameters, namely $\mu$ and $\sigma$.
#
# The PDF of the Normal distribution is as follows:
#
# $p(x) = \frac{1}{{\sigma\sqrt{2\pi}}}e^{-\frac{1}{2}(\frac{x-\mu}{\sigma})^2}$
#
# Let's get a better understanding of how different values of the parameters $\mu$ and $\sigma$ influence the shape of the distribution.

# %% [markdown]
# First, let's get $n = 1000$ samples from the **standard** normal distribution, for which $\mu$ = 0 and $\sigma$ = 1.
#
# *Hint: you can do so with the help of the [np.random.normal()](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) function.*

# %%
n = 1000

# Your code here

# %% [markdown]
# Now, compute the values of the probability density function of the normal destribution over the same range of values as you sampled.
#
# Remember that for now, $\mu = 0$ and $\sigma = 1$.

# %%
# Your code here

# %% [markdown]
# Plot the histogram of the sampled data. Then, add the PDF you've computed at the previous step to see how similar the theoretical (PDF) and empirical (histogram of the sampled data) distributions are.
#
# *Hint: you can use sns.histplot() to plot the histogram. Don't forget to normalize the bar heights of your histogram appropriately by specifying the value of the stats parameter.  To add the PDF curve on the plot, use, for example, plt.plot()*

# %%
# Your code here

# %% [markdown]
# How will the plot look like if you change the values of the parameters of the distribution?
#
# Make more plots in order to investigate how the theoretical shape of the distribution (the PDF) and the smaples change depending on the parameter values.

# %%
# Your code here
